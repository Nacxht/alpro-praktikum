# %% [markdown]
# # 1. Buatkan program untuk implementasi deret aritmatika. Inputan berupa suku awal, pembeda, banyak bilangan kemudian hitung jumlah seluruh bilangan!
#
# Contoh output:
# > ![image.png](data:image/png;base64,...)

# %%
sukuAwal = int(input("Masukkan suku awal(a): "))
pembeda = int(input("Masukkan pembeda (b): "))
banyakBilangan = int(input("Masukkan banyak bilangan: "))

jumlahSeluruhBilangan = 0
i = 0

for i in range(banyakBilangan):
  print(sukuAwal, end=" ")

  jumlahSeluruhBilangan += sukuAwal
  sukuAwal += pembeda

print(f"\nJumlah seluruh bilangan: {float(jumlahSeluruhBilangan)}")
# Out:
# Masukkan suku awal(a): 10
# Masukkan pembeda (b): -2
# Masukkan banyak bilangan: 10
# 10 8 6 4 2 0 -2 -4 -6 -8
# Jumlah seluruh bilangan: 10.0

# %% [markdown]
# # 2. Buatlah program Kalkulator sederhana yang mengandung operator penambahan, pengurangan, perkalian, dan pembagian.
#
# Contoh output:
# > ![image.png](data:image/png;base64,...)

# %%
while True:
  print("=== Kalkulator Sederhana ===")
  print("Pilih Operasi:")
  print("1. Tambah (+)")
  print("2. Kurang (-)")
  print("3. Kali (*)")
  print("4. Bagi (/)")
  print("5. Exit")

  menuInput = input("Masukkan pilihan (1/2/3//4/5): ")

  if menuInput == "1":
    angkaPertama = float(input("Masukkan angka pertama: "))
    angkaKedua = float(input("Masukkan angka kedua: "))
    hasil = angkaPertama + angkaKedua

    print(f"\nHasil: {angkaPertama} + {angkaKedua} = {hasil}\n")
  elif menuInput == "2":
    angkaPertama = float(input("Masukkan angka pertama: "))
    angkaKedua = float(input("Masukkan angka kedua: "))
    hasil = angkaPertama - angkaKedua

    print(f"\nHasil: {angkaPertama} - {angkaKedua} = {hasil}\n")
  elif menuInput == "3":
    angkaPertama = float(input("Masukkan angka pertama: "))
    angkaKedua = float(input("Masukkan angka kedua: "))
    hasil = angkaPertama * angkaKedua

    print(f"\nHasil: {angkaPertama} * {angkaKedua} = {hasil}\n")
  elif menuInput == "4":
    angkaPertama = float(input("Masukkan angka pertama: "))
    angkaKedua = float(input("Masukkan angka kedua: "))
    hasil = angkaPertama / angkaKedua

    print(f"\nHasil: {angkaPertama} / {angkaKedua} = {hasil}\n")
  elif menuInput == "5":
    print("Terima kasih telah menggunakan kalkulator. Sampai jumpa!")
    break
  else:
    print("Pilihan tidak valid. Silahkan coba lagi.\n")
# Out:
# === Kalkulator Sederhana ===
# Pilih Operasi:
# 1. Tambah (+)
# 2. Kurang (-)
# 3. Kali (*)
# 4. Bagi (/)
# 5. Exit
# Masukkan pilihan (1/2/3//4/5): 5
# Terima kasih telah menggunakan kalkulator. Sampai jumpa!

# %% [markdown]
# # 3. Bilangan dua pangkat adalah bilangan bulat yang dapat dinyatakan dalam bentuk 2^k, dengan K adalah suatu bilangan bulat. Pak Hadi memberikan Anda sebuah bilangan bulat N. Tentukan apakah N adalah bilangan "dua pangkat" atau bukan.
#
# **Format masukan:**
# > Baris pertama berisi sebuah bilangan bulat N.
#
# **Format keluaran:**
# > Sebuah baris berisi "ya" apabila N adalah bilangan dua pangkat, atau "bukan" apabila bukan.
#
# **Contoh output:**
# > ![image.png](data:image/png;base64,...)
# > ![image.png](data:image/png;base64,...)
#
# **Petunjuk:**
# Jika bilangan N adalah bilangan genap maka periksalah menggunakan perulangan dengan pola yang menunjukkan bilangan tersebut adalah bilangan dua pangkat.

# %%
num = int(input("Masukkan N: "))
apakahDuaPangkat = False

for i in range(num):
  duaPangkat = 2 ** (i + 1)

  if num == duaPangkat:
    apakahDuaPangkat = True
    break
  elif duaPangkat > num:
    break

if apakahDuaPangkat == True:
  print("ya")
else:
  print("bukan")
# Out:
# Masukkan N: 9
# bukan

# %%
n = int(input())
byte = 1

for i in range(n):
  print(" " * (n - i), end="")

  for j in range(1, i + 1):
    print(byte, end=" ")
    byte += byte

  print(" " * (n - i), end="")
  print()
# Out:
# 5
#
#     1
#    2 4
#   8 16 32
#  64 128 256 512
