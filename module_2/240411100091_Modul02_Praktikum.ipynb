# %% [markdown]
# # Tuliskan program kalkulator arimatika, yang Dimana operator dan angka berupa input dari user.
#
# **Contoh output:**
# > ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
print("========= KALKULATOR ARITMATIKA =========")

firstNumber = int(input("angka: "))
operator = input("operator (+, -, *, /, //, **, %): ")
secondNumber = int(input("angka: "))

if operator == "+":
  print(f"Hasil: {firstNumber + secondNumber}")
elif operator == "-":
  print(f"Hasil: {firstNumber - secondNumber}")
elif operator == "*":
  print(f"Hasil: {firstNumber * secondNumber}")
elif operator == "/":
  print(f"Hasil: {firstNumber / secondNumber}")
elif operator == "//":
  print(f"Hasil: {firstNumber // secondNumber}")
elif operator == "**":
  print(f"Hasil: {firstNumber ** secondNumber}")
elif operator == "%":
  print(f"Hasil: {firstNumber % secondNumber}")
else:
  print("Operator tidak ditemukan!")

print("========= PROGRAM SELESAI =========")
# Out:
# ========= KALKULATOR ARITMATIKA =========
# angka: 5
# operator (+, -, *, /, //, **, %): /
# angka: 3
# Hasil: 1.6666666666666667
# ========= PROGRAM SELESAI =========

# %% [markdown]
# # Buatlah kode program untuk menghitung jumlah yang harus dibayarkan konsumen pusat perbelanjaan dengan ketentuan sebagai berikut:
#
# 1. Terdapat 2 jenis konsumen yaitu member dan non-member.
# 2. Apabila total belanja lebih dari 100.000 maka berhak mendapatkan diskon 3 persen.
# 3. Apabila total belanja lebih dari 200.000 maka berhak mendapatkan diskon 4 persen.
# 4. Setiap pembelian yang dilakukan oleh member mendapatkan tambahan diskon 2 persen.
#
# **Contoh output:**
# > ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
isMember = input("Status: (member/tidak): ")
totalPrice = int(input("Masukkan total belanja: "))

discount = 0

if isMember == "member":
  discount += 2

if totalPrice > 200000:
  discount += 4
elif totalPrice > 100000:
  discount += 3

discountToIdr = discount / 100 * totalPrice
mustPaid = totalPrice - (totalPrice * discount / 100)

print(f"Total diskon: {discountToIdr}")
print(f"Total yang harus dibayar: {mustPaid}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b5cdcb8bb10c> in <cell line: 1>()
# ----> 1 isMember = input("Status: (member/tidak): ")
#       2 totalPrice = int(input("Masukkan total belanja: "))
#       3
#       4 discount = 0
#       5
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Buatlah kode program untuk membuat user baru pada sebuah sistem, dengan ketentuan sebagai berikut:
#
# 1. User perlu memasukkan username, email, dan password.
# 2. User baru hanya akan sukses dibuat apabila:
#  - Username tidak boleh kosong.
#  - Terdapat "@" pada alamat email.
#  - Panjang password lebih dari 8 karakter.
#
# **Contoh output:**
# > ![image.png](data:image/png;base64,...)
#
# > ![image.png](data:image/png;base64,...)
#
# > ![image.png](data:image/png;base64,...)
#
# > ![image.png](data:image/png;base64,...)

# %%
username = input("Masukkan Username: ")
email = input("Masukkan Email: ")
password = input("Masukkan Password: ")
bornYear = int(input("Masukkan tahun lahir anda: "))

if not username:
  print("Invalid, Username tidak boleh kosong")
elif "@" not in email:
  print("Invalid, Email tidak valid, gunakan @ pada email")
elif len(password) <= 8:
  print("Invalid, Password harus lebih dari 8 karakter")
elif bornYear >= 2000:
  print("Anda belum cukup umur")
else:
  print("Akun berhasil dibuat")
# Out:
# Masukkan Username:
# Masukkan Email:
# Masukkan Password:
# Masukkan tahun lahir anda: 2008
# Invalid, Username tidak boleh kosong
